# %%
from IPython.core.display import HTML
HTML("""
<style>
.container {
    width: 95% !important;
}
</style>
""")
# Out:
# <style>
# .container {
#     width: 95% !important;
# }
# </style>

# %%
import pandas as pd


# 제주 데이터 허브 [소비, 경제] 제주특별자치도_주제3_상권분석을 위한 유동인구에 따른 카드 매출액 변화 데이터 활용_매쉬업결과]
# https://www.jejudatahub.net/data/view/data/748

df = pd.read_csv('jeju_card_sales.csv', encoding = 'cp949')


# 제주 데이터 허브 [소비, 경제] 제주특별자치도_주제1_제주 예비창업자를 위한 업종별 카드 매출과 매장수 데이터 활용_매쉬업 결과]
# https://www.jejudatahub.net/data/view/data/746

df_person = pd.read_csv('jeju_card_person.csv', encoding = 'cp949')

# %%
df.head(20)
# Out:
#             년월   시도명 읍면동명                      업종명  성별   이용자수       이용금액  \
# 0   2020-01-01  서귀포시  남원읍                  골프장 운영업  남성   1980  297727940
# 1   2020-01-01   제주시  외도동                  수산물 소매업  남성     75    4657000
# 2   2020-01-01   제주시  오라동                  중식 음식점업  남성    283    9340000
# 3   2020-01-01   제주시  오라동                  자동차 임대업  남성    293   16523986
# 4   2020-01-01   제주시  오라동       스포츠 및 레크레이션 용품 임대업  남성    407   37918500
# 5   2020-01-01   제주시  오라동                  한식 음식점업  남성   9694  285666860
# 6   2020-01-01   제주시  오라동                  체인화 편의점  남성   8210   68812010
# 7   2020-01-01   제주시  오라동              차량용 주유소 운영업  남성   6245  315006743
# 8   2020-01-01   제주시  오라동               차량용 가스 충전업  남성    206   10271460
# 9   2020-01-01   제주시  오라동            화장품 및 방향제 소매업  남성      2    2280000
# 10  2020-01-01   제주시  오라동                  골프장 운영업  여성    210   25657753
# 11  2020-01-01   제주시  오라동                 일반유흥 주점업  남성      8    1510000
# ...

# %%
df_person.head(20)
# Out:
#          년월  시도명 지역구분  읍면동명    업종코드  업종명 이용자 구분 관광구분   연령대    성별     이용금액  \
# 0   2021-01  제주시   도심  삼도일동  S96121  욕탕업     법인   단체   NaN  알수없음   160000
# 1   2021-01  제주시   읍면   한림읍  S96121  욕탕업    내국인   개별  70.0    남성    10000
# 2   2021-01  제주시   읍면   구좌읍  S96121  욕탕업   제주도민   도민  40.0    남성    15000
# 3   2021-01  제주시   도심  도두일동  S96121  욕탕업     법인   단체   NaN  알수없음    56000
# 4   2021-01  제주시   도심  삼도이동  S96121  욕탕업   제주도민   도민  70.0    남성  1154000
# 5   2021-01  제주시   도심  삼양이동  S96121  욕탕업    내국인   단체  20.0    여성     5000
# 6   2021-01  제주시   도심  삼양이동  S96121  욕탕업   제주도민   도민  40.0    여성    40000
# 7   2021-01  제주시   도심  도두일동  S96121  욕탕업    내국인   단체  20.0    여성    16000
# 8   2021-01  제주시   읍면   한림읍  S96121  욕탕업   제주도민   도민  60.0    남성    26000
# 9   2021-01  제주시   도심  화북이동  S96121  욕탕업    내국인   개별  20.0    남성     6000
# 10  2021-01  제주시   도심  도두일동  S96121  욕탕업   제주도민   도민  60.0    남성   189000
# 11  2021-01  제주시   도심  아라일동  S96121  욕탕업    내국인   개별  30.0    남성     8000
# ...
